# %%
# !pip install gokinjo scikit-learn
# !pip install autogluon
# !pip install --upgrade ipykernel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gokinjo in c:\users\aluno\appdata\roaming\python\python311\site-packages (0.1.0)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from gokinjo) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: autogluon in c:\users\aluno\appdata\roaming\python\python311\site-packages (1.1.1b20240423)
# Requirement already satisfied: autogluon.core[all]==1.1.1b20240423 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon) (1.1.1b20240423)
# Requirement already satisfied: autogluon.features==1.1.1b20240423 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon) (1.1.1b20240423)
# Requirement already satisfied: autogluon.tabular[all]==1.1.1b20240423 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon) (1.1.1b20240423)
# Requirement already satisfied: autogluon.multimodal==1.1.1b20240423 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon) (1.1.1b20240423)
# Requirement already satisfied: autogluon.timeseries[all]==1.1.1b20240423 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon) (1.1.1b20240423)
# Requirement already satisfied: numpy<1.29,>=1.21 in c:\programdata\anaconda3\lib\site-packages (from autogluon.core[all]==1.1.1b20240423->autogluon) (1.24.3)
# Requirement already satisfied: scipy<1.13,>=1.5.4 in c:\programdata\anaconda3\lib\site-packages (from autogluon.core[all]==1.1.1b20240423->autogluon) (1.11.1)
# Requirement already satisfied: scikit-learn<1.4.1,>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from autogluon.core[all]==1.1.1b20240423->autogluon) (1.3.0)
# Requirement already satisfied: networkx<4,>=3.0 in c:\programdata\anaconda3\lib\site-packages (from autogluon.core[all]==1.1.1b20240423->autogluon) (3.1)
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from autogluon.core[all]==1.1.1b20240423->autogluon) (2.0.3)
# Requirement already satisfied: tqdm<5,>=4.38 in c:\programdata\anaconda3\lib\site-packages (from autogluon.core[all]==1.1.1b20240423->autogluon) (4.65.0)
# Requirement already satisfied: requests in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.core[all]==1.1.1b20240423->autogluon) (2.28.2)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from autogluon.core[all]==1.1.1b20240423->autogluon) (3.7.2)
# Requirement already satisfied: boto3<2,>=1.10 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.core[all]==1.1.1b20240423->autogluon) (1.34.90)
# Requirement already satisfied: autogluon.common==1.1.1b20240423 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.core[all]==1.1.1b20240423->autogluon) (1.1.1b20240423)
# Requirement already satisfied: ray[default,tune]<2.11,>=2.10.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.core[all]==1.1.1b20240423->autogluon) (2.10.0)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.core[all]==1.1.1b20240423->autogluon) (0.2.7)
# Requirement already satisfied: Pillow<11,>=10.0.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (10.3.0)
# Requirement already satisfied: torch<2.2,>=2.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (2.1.2)
# Requirement already satisfied: lightning<2.2,>=2.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (2.1.4)
# Requirement already satisfied: transformers[sentencepiece]<4.39.0,>=4.38.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (4.38.2)
# Requirement already satisfied: accelerate<0.22.0,>=0.21.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (0.21.0)
# Requirement already satisfied: jsonschema<4.22,>=4.18 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (4.21.1)
# Requirement already satisfied: seqeval<1.3.0,>=1.2.2 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (1.2.2)
# Requirement already satisfied: evaluate<0.5.0,>=0.4.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (0.4.1)
# Requirement already satisfied: timm<0.10.0,>=0.9.5 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (0.9.16)
# Requirement already satisfied: torchvision<0.17.0,>=0.16.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (0.16.2)
# Requirement already satisfied: scikit-image<0.21.0,>=0.19.1 in c:\programdata\anaconda3\lib\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (0.20.0)
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in c:\programdata\anaconda3\lib\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (1.3)
# Requirement already satisfied: torchmetrics<1.3.0,>=1.2.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (1.2.1)
# Requirement already satisfied: nptyping<2.5.0,>=1.4.4 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (2.4.1)
# Requirement already satisfied: omegaconf<2.3.0,>=2.1.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (2.2.3)
# Requirement already satisfied: pytorch-metric-learning<2.4,>=1.3.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (2.3.0)
# Requirement already satisfied: nlpaug<1.2.0,>=1.1.10 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (1.1.11)
# Requirement already satisfied: nltk<4.0.0,>=3.4.5 in c:\programdata\anaconda3\lib\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (3.8.1)
# Requirement already satisfied: openmim<0.4.0,>=0.3.7 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (0.3.9)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (0.7.1)
# Requirement already satisfied: jinja2<3.2,>=3.0.3 in c:\programdata\anaconda3\lib\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (3.1.2)
# Requirement already satisfied: tensorboard<3,>=2.9 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (2.16.2)
# Requirement already satisfied: pytesseract<0.3.11,>=0.3.9 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (0.3.10)
# Requirement already satisfied: nvidia-ml-py3==7.352.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (7.352.0)
# Requirement already satisfied: pdf2image<1.19,>=1.17.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.multimodal==1.1.1b20240423->autogluon) (1.17.0)
# Requirement already satisfied: lightgbm<4.4,>=3.3 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.tabular[all]==1.1.1b20240423->autogluon) (4.3.0)
# Requirement already satisfied: fastai<2.8,>=2.3.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.tabular[all]==1.1.1b20240423->autogluon) (2.7.14)
# Requirement already satisfied: xgboost<2.1,>=1.6 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.tabular[all]==1.1.1b20240423->autogluon) (2.0.3)
# Requirement already satisfied: catboost<1.3,>=1.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.tabular[all]==1.1.1b20240423->autogluon) (1.2.5)
# Requirement already satisfied: joblib<2,>=1.1 in c:\programdata\anaconda3\lib\site-packages (from autogluon.timeseries[all]==1.1.1b20240423->autogluon) (1.2.0)
# Requirement already satisfied: pytorch-lightning<2.2,>=2.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.timeseries[all]==1.1.1b20240423->autogluon) (2.1.4)
# Requirement already satisfied: gluonts<0.14.4,>=0.14.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.timeseries[all]==1.1.1b20240423->autogluon) (0.14.3)
# Requirement already satisfied: statsforecast<1.5,>=1.4.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.timeseries[all]==1.1.1b20240423->autogluon) (1.4.0)
# Requirement already satisfied: mlforecast<0.10.1,>=0.10.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.timeseries[all]==1.1.1b20240423->autogluon) (0.10.0)
# Requirement already satisfied: utilsforecast<0.0.11,>=0.0.10 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.timeseries[all]==1.1.1b20240423->autogluon) (0.0.10)
# Requirement already satisfied: orjson~=3.9 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.timeseries[all]==1.1.1b20240423->autogluon) (3.10.1)
# Requirement already satisfied: optimum[onnxruntime]<1.19,>=1.17 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.timeseries[all]==1.1.1b20240423->autogluon) (1.18.1)
# Requirement already satisfied: psutil<6,>=5.7.3 in c:\programdata\anaconda3\lib\site-packages (from autogluon.common==1.1.1b20240423->autogluon.core[all]==1.1.1b20240423->autogluon) (5.9.0)
# Requirement already satisfied: setuptools in c:\users\aluno\appdata\roaming\python\python311\site-packages (from autogluon.common==1.1.1b20240423->autogluon.core[all]==1.1.1b20240423->autogluon) (60.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from accelerate<0.22.0,>=0.21.0->autogluon.multimodal==1.1.1b20240423->autogluon) (23.1)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from accelerate<0.22.0,>=0.21.0->autogluon.multimodal==1.1.1b20240423->autogluon) (6.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.90 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from boto3<2,>=1.10->autogluon.core[all]==1.1.1b20240423->autogluon) (1.34.90)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from boto3<2,>=1.10->autogluon.core[all]==1.1.1b20240423->autogluon) (0.10.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from boto3<2,>=1.10->autogluon.core[all]==1.1.1b20240423->autogluon) (0.10.1)
# Requirement already satisfied: graphviz in c:\users\aluno\appdata\roaming\python\python311\site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (0.20.3)
# Requirement already satisfied: plotly in c:\programdata\anaconda3\lib\site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (5.9.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (1.16.0)
# Requirement already satisfied: datasets>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.1b20240423->autogluon) (2.12.0)
# Requirement already satisfied: dill in c:\programdata\anaconda3\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.1b20240423->autogluon) (0.3.6)
# Requirement already satisfied: xxhash in c:\programdata\anaconda3\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.1b20240423->autogluon) (2.0.2)
# Requirement already satisfied: multiprocess in c:\programdata\anaconda3\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.1b20240423->autogluon) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.1b20240423->autogluon) (2024.3.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.1b20240423->autogluon) (0.22.2)
# Requirement already satisfied: responses<0.19 in c:\programdata\anaconda3\lib\site-packages (from evaluate<0.5.0,>=0.4.0->autogluon.multimodal==1.1.1b20240423->autogluon) (0.13.3)
# Requirement already satisfied: pip in c:\programdata\anaconda3\lib\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (23.2.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (1.5.29)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (1.0.3)
# Requirement already satisfied: spacy<4 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (3.7.4)
# Requirement already satisfied: pydantic<3,>=1.7 in c:\programdata\anaconda3\lib\site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (1.10.8)
# Requirement already satisfied: toolz~=0.10 in c:\programdata\anaconda3\lib\site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (0.12.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\programdata\anaconda3\lib\site-packages (from gluonts<0.14.4,>=0.14.0->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (4.7.1)
# Requirement already satisfied: future in c:\programdata\anaconda3\lib\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.1b20240423->autogluon) (0.18.3)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.1b20240423->autogluon) (2.2.1)
# Requirement already satisfied: py4j in c:\users\aluno\appdata\roaming\python\python311\site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==1.1.1b20240423->autogluon) (0.10.9.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2<3.2,>=3.0.3->autogluon.multimodal==1.1.1b20240423->autogluon) (2.1.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.1b20240423->autogluon) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.1b20240423->autogluon) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.1b20240423->autogluon) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from jsonschema<4.22,>=4.18->autogluon.multimodal==1.1.1b20240423->autogluon) (0.18.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from lightning<2.2,>=2.1->autogluon.multimodal==1.1.1b20240423->autogluon) (0.11.2)
# Requirement already satisfied: numba in c:\programdata\anaconda3\lib\site-packages (from mlforecast<0.10.1,>=0.10.0->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (0.57.1)
# Requirement already satisfied: window-ops in c:\users\aluno\appdata\roaming\python\python311\site-packages (from mlforecast<0.10.1,>=0.10.0->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (0.0.15)
# Requirement already satisfied: gdown>=4.0.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.1b20240423->autogluon) (5.1.0)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==1.1.1b20240423->autogluon) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==1.1.1b20240423->autogluon) (2022.7.9)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\aluno\appdata\roaming\python\python311\site-packages (from omegaconf<2.3.0,>=2.1.1->autogluon.multimodal==1.1.1b20240423->autogluon) (4.9.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (0.4.6)
# Requirement already satisfied: model-index in c:\users\aluno\appdata\roaming\python\python311\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (0.1.11)
# Requirement already satisfied: opendatalab in c:\users\aluno\appdata\roaming\python\python311\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (0.0.10)
# Requirement already satisfied: rich in c:\users\aluno\appdata\roaming\python\python311\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (13.4.2)
# Requirement already satisfied: tabulate in c:\programdata\anaconda3\lib\site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (0.8.10)
# Requirement already satisfied: coloredlogs in c:\users\aluno\appdata\roaming\python\python311\site-packages (from optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (15.0.1)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (1.11.1)
# Requirement already satisfied: onnx in c:\users\aluno\appdata\roaming\python\python311\site-packages (from optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (1.16.0)
# Requirement already satisfied: onnxruntime>=1.11.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (1.17.3)
# Requirement already satisfied: protobuf>=3.20.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (4.25.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core[all]==1.1.1b20240423->autogluon) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core[all]==1.1.1b20240423->autogluon) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<2.3.0,>=2.0.0->autogluon.core[all]==1.1.1b20240423->autogluon) (2023.3)
# Requirement already satisfied: filelock in c:\users\aluno\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (3.13.4)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (1.0.3)
# Requirement already satisfied: aiosignal in c:\programdata\anaconda3\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (1.2.0)
# Requirement already satisfied: frozenlist in c:\programdata\anaconda3\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (1.3.3)
# Requirement already satisfied: aiohttp>=3.7 in c:\programdata\anaconda3\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (3.8.5)
# Requirement already satisfied: aiohttp-cors in c:\users\aluno\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (0.7.0)
# Requirement already satisfied: colorful in c:\users\aluno\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (0.3.14)
# Requirement already satisfied: opencensus in c:\users\aluno\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (0.11.4)
# Requirement already satisfied: prometheus-client>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (0.14.1)
# Requirement already satisfied: smart-open in c:\programdata\anaconda3\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (5.2.1)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (20.26.0)
# Requirement already satisfied: grpcio>=1.42.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (1.62.2)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\programdata\anaconda3\lib\site-packages (from ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (11.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->autogluon.core[all]==1.1.1b20240423->autogluon) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->autogluon.core[all]==1.1.1b20240423->autogluon) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->autogluon.core[all]==1.1.1b20240423->autogluon) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->autogluon.core[all]==1.1.1b20240423->autogluon) (2023.7.22)
# Requirement already satisfied: imageio>=2.4.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.1b20240423->autogluon) (2.26.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\programdata\anaconda3\lib\site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.1b20240423->autogluon) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.1b20240423->autogluon) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-image<0.21.0,>=0.19.1->autogluon.multimodal==1.1.1b20240423->autogluon) (0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn<1.4.1,>=1.3.0->autogluon.core[all]==1.1.1b20240423->autogluon) (2.2.0)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\programdata\anaconda3\lib\site-packages (from statsforecast<1.5,>=1.4.0->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (0.14.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.1b20240423->autogluon) (2.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.1b20240423->autogluon) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.1b20240423->autogluon) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==1.1.1b20240423->autogluon) (2.2.3)
# Requirement already satisfied: safetensors in c:\users\aluno\appdata\roaming\python\python311\site-packages (from timm<0.10.0,>=0.9.5->autogluon.multimodal==1.1.1b20240423->autogluon) (0.4.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.1b20240423->autogluon) (0.15.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from transformers[sentencepiece]<4.39.0,>=4.38.0->autogluon.multimodal==1.1.1b20240423->autogluon) (0.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->autogluon.core[all]==1.1.1b20240423->autogluon) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->autogluon.core[all]==1.1.1b20240423->autogluon) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->autogluon.core[all]==1.1.1b20240423->autogluon) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->autogluon.core[all]==1.1.1b20240423->autogluon) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->autogluon.core[all]==1.1.1b20240423->autogluon) (3.0.9)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp>=3.7->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (1.8.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.1b20240423->autogluon) (4.12.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\programdata\anaconda3\lib\site-packages (from numba->mlforecast<0.10.1,>=0.10.0->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (0.40.0)
# Requirement already satisfied: flatbuffers in c:\users\aluno\appdata\roaming\python\python311\site-packages (from onnxruntime>=1.11.0->optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (24.3.25)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (0.9.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (3.3.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\programdata\anaconda3\lib\site-packages (from statsmodels>=0.13.2->statsforecast<1.5,>=1.4.0->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (0.5.3)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (0.3.8)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\programdata\anaconda3\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (3.10.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from coloredlogs->optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (10.0)
# Requirement already satisfied: ordered-set in c:\users\aluno\appdata\roaming\python\python311\site-packages (from model-index->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (4.1.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (2.18.0)
# Requirement already satisfied: pycryptodome in c:\users\aluno\appdata\roaming\python\python311\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (3.20.0)
# Requirement already satisfied: openxlab in c:\users\aluno\appdata\roaming\python\python311\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (0.0.38)
# Requirement already satisfied: pywin32 in c:\programdata\anaconda3\lib\site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (305.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from plotly->catboost<1.3,>=1.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (8.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (2.15.1)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (1.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (1.63.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (1.23.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (2.29.0)
# Requirement already satisfied: pyreadline3 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from humanfriendly>=9.1->coloredlogs->optimum[onnxruntime]<1.19,>=1.17->autogluon.timeseries[all]==1.1.1b20240423->autogluon) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (0.1.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==1.1.1b20240423->autogluon) (0.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==1.1.1b20240423->autogluon) (2.4)
# Requirement already satisfied: oss2~=2.17.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (2.17.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from requests->autogluon.core[all]==1.1.1b20240423->autogluon) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (4.9)
# Requirement already satisfied: crcmod>=1.7 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (2.16.2)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (2.15.1)
# Requirement already satisfied: cryptography>=2.6.0 in c:\programdata\anaconda3\lib\site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (41.0.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<2.11,>=2.10.0->autogluon.core[all]==1.1.1b20240423->autogluon) (0.4.8)
# Requirement already satisfied: cffi>=1.12 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (1.15.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==1.1.1b20240423->autogluon) (2.21)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipykernel in c:\users\aluno\appdata\roaming\python\python311\site-packages (6.29.4)
# Requirement already satisfied: comm>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\programdata\anaconda3\lib\site-packages (from ipykernel) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel) (8.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\programdata\anaconda3\lib\site-packages (from ipykernel) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\programdata\anaconda3\lib\site-packages (from ipykernel) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from ipykernel) (1.5.6)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from ipykernel) (23.1)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from ipykernel) (26.0.2)
# Requirement already satisfied: tornado>=6.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.18.1)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.15.1)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: entrypoints in c:\programdata\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (305.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.5)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)

# %%
# general packages
import pandas as pd
import numpy as np
import time

# knn features
import gokinjo
from gokinjo import knn_kfold_extract
from gokinjo import knn_extract

# ml tools
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import f1_score, log_loss, roc_auc_score

# models
from catboost import CatBoostClassifier
from xgboost import XGBClassifier

# optimization
import optuna

# interpretable ml
import shap

# automl
from autogluon.tabular import TabularPredictor

# ignore specific warnings
import warnings
warnings.filterwarnings("ignore", message="ntree_limit is deprecated, use `iteration_range` or model slicing instead.")

# %%
# aux functions

def get_threshold(y_true, y_pred):
    thresholds = np.arange(0.0, 1.0, 0.01)
    f1_scores = []
    for thresh in thresholds:
        f1_scores.append(
            f1_score(y_true, [1 if m>thresh else 0 for m in y_pred]))
    f1s = np.array(f1_scores)
    return thresholds[f1s.argmax()]
    
def custom_f1(y_true, y_pred):
    max_f1_threshold =  get_threshold(y_true, y_pred)
    y_pred = np.where(y_pred>max_f1_threshold, 1, 0)
    return f1_score(y_true, y_pred)

# %%
# load data
train = pd.read_csv('../datasets/train.csv').drop('id', axis=1)
test = pd.read_csv('../datasets/test.csv').drop('id', axis=1)
sample_submission = pd.read_csv('../datasets/submission_sample.csv')
meta = pd.read_csv('../datasets/metadata.csv')

# get data types
cat_nom = [x for x in meta.iloc[1:-1, :].loc[(meta.iloc[:,1]=="Qualitativo nominal")].iloc[:,0]] 
cat_ord = [x for x in meta.iloc[1:-1, :].loc[(meta.iloc[:,1]=="Qualitativo ordinal")].iloc[:,0]] 
num_dis = [x for x in meta.iloc[1:-1, :].loc[(meta.iloc[:,1]=="Quantitativo discreto")].iloc[:,0]] 
num_con = [x for x in meta.iloc[1:-1, :].loc[(meta.iloc[:,1]=="Quantitativo continua")].iloc[:,0]]

# %%
# convert to numpy because gokinjo expects np arrays
X = train[cat_nom+cat_ord+num_dis+num_con].to_numpy()
y = train.y.to_numpy()
X_test = test[cat_nom+cat_ord+num_dis+num_con].to_numpy()

# extract on train data
KNN_feat_train = knn_kfold_extract(X, y, k=1, normalize='standard')
print("KNN features for training set, shape: ", np.shape(KNN_feat_train))

# extract on test data
KNN_feat_test = knn_extract(X, y, X_test, k=1, normalize='standard')
print("KNN features for test set, shape: ", np.shape(KNN_feat_test))

# convert to dataframe
KNN_feat_train = pd.DataFrame(KNN_feat_train, columns=["knn"+str(x) for x in range(KNN_feat_train.shape[1])])
KNN_feat_test = pd.DataFrame(KNN_feat_test, columns=["knn"+str(x) for x in range(KNN_feat_test.shape[1])])

# store KNN features, they are computationally expensive
KNN_feat_train.to_csv('../datasets/knn_feat_train.csv',index=False)
KNN_feat_test.to_csv('../datasets/knn_feat_test.csv',index=False)
# Out:
# KNN features for training set, shape:  (14123, 2)
# KNN features for test set, shape:  (21183, 2)

# %%
knn_feat_train = pd.read_csv('../datasets/knn_feat_train.csv')
knn_feat_test = pd.read_csv('../datasets/knn_feat_test.csv')

# %% [markdown]
# # Stage 1: Tune XGBoost¶

# %%
X_test = test[cat_nom+cat_ord+num_dis+num_con]
X = train[cat_nom+cat_ord+num_dis+num_con]
y = train.y

K=10
SEED=314
kf = KFold(n_splits=K, random_state=SEED, shuffle=True)

# %%
fixed_params = {
    'random_state': 9,
    "objective": "binary:logistic",
    "eval_metric": 'logloss',
    'use_label_encoder':False,
    'n_estimators':10000,
}

def objective(trial):
    
    hyperparams = {
        'clf':{
        "booster": trial.suggest_categorical("booster", ["gbtree"]),
        "lambda": trial.suggest_float("lambda", 1e-8, 5.0, log=True),
        "alpha": trial.suggest_float("alpha", 1e-8, 5.0, log=True)
        }
    }
    
    if hyperparams['clf']["booster"] == "gbtree" or hyperparams['clf']["booster"] == "dart":
        hyperparams['clf']["max_depth"] = trial.suggest_int("max_depth", 1, 9)
        hyperparams['clf']["eta"] = trial.suggest_float("eta", 0.01, 0.1, log=True)
        hyperparams['clf']["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
        hyperparams['clf']["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])
        hyperparams['clf']['min_child_weight'] = trial.suggest_int('min_child_weight', 5, 20)
        hyperparams['clf']["subsample"] = trial.suggest_float("subsample", 0.03, 1)
        hyperparams['clf']["colsample_bytree"] = trial.suggest_float("colsample_bytree", 0.03, 1)
        hyperparams['clf']['max_delta_step'] = trial.suggest_float('max_delta_step', 0, 10)
        
    if hyperparams['clf']["booster"] == "dart":
        hyperparams['clf']["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
        hyperparams['clf']["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
        hyperparams['clf']["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
        hyperparams['clf']["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)
    
    params = dict(**fixed_params, **hyperparams['clf'])
    
    xgb_oof = np.zeros(X.shape[0])

    for fold, (train_idx, val_idx) in enumerate(kf.split(X=X, y=y)):
        X_train = X.iloc[train_idx]
        y_train = y.iloc[train_idx]
        X_val = X.iloc[val_idx]
        y_val = y.iloc[val_idx]
        
        model = XGBClassifier(**params)
        
        model.fit(X_train, y_train,
                  eval_set=[(X_val, y_val)],
                  early_stopping_rounds=150,
                  verbose=False)
    
        xgb_oof[val_idx] = model.predict_proba(X_val)[:,1]

        del model

    return log_loss(y, xgb_oof)

# %%
study_xgb = optuna.create_study(direction='minimize')

study_xgb.optimize(objective, 
               timeout=60*5, # original time: 60*60*7.5
               gc_after_trial=True)
# Out:
# [I 2024-04-23 20:57:20,138] A new study created in memory with name: no-name-f0630edb-2a06-441e-8a70-2ce4df01f357
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-04-23 20:57:52,175] Trial 0 finished with value: 0.3084513667228177 and parameters: {'booster': 'gbtree', 'lambda': 0.12143389113963737, 'alpha': 5.623595141779514e-06, 'max_depth': 8, 'eta': 0.04301348897337207, 'gamma': 1.8649623788840534e-06, 'grow_policy': 'lossguide', 'min_child_weight': 8, 'subsample': 0.7928008286439018, 'colsample_bytree': 0.6206135011258861, 'max_delta_step': 9.087090875582511}. Best is trial 0 with value: 0.3084513667228177.
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-04-23 20:58:16,066] Trial 1 finished with value: 0.35715860974439667 and parameters: {'booster': 'gbtree', 'lambda': 2.339804285246967e-07, 'alpha': 0.707721263993262, 'max_depth': 7, 'eta': 0.05712099129176861, 'gamma': 1.5737631645070655e-05, 'grow_policy': 'depthwise', 'min_child_weight': 18, 'subsample': 0.03162718782916472, 'colsample_bytree': 0.6827389104364315, 'max_delta_step': 6.190624190143659}. Best is trial 0 with value: 0.3084513667228177.
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-04-23 20:58:51,009] Trial 2 finished with value: 0.3139906025268392 and parameters: {'booster': 'gbtree', 'lambda': 0.0009587047148253532, 'alpha': 3.0434749014302073e-06, 'max_depth': 1, 'eta': 0.039305329704259845, 'gamma': 0.00020053868416788247, 'grow_policy': 'lossguide', 'min_child_weight': 5, 'subsample': 0.36597948645029177, 'colsample_bytree': 0.40723092407754424, 'max_delta_step': 7.841119734355568}. Best is trial 0 with value: 0.3084513667228177.
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-04-23 20:59:07,551] Trial 3 finished with value: 0.30706386714273903 and parameters: {'booster': 'gbtree', 'lambda': 2.158480344020655e-05, 'alpha': 0.00013804434905441334, 'max_depth': 3, 'eta': 0.07826171430110693, 'gamma': 0.00019544522705132708, 'grow_policy': 'lossguide', 'min_child_weight': 15, 'subsample': 0.8179199186157516, 'colsample_bytree': 0.17724110980420985, 'max_delta_step': 2.4808312556147447}. Best is trial 3 with value: 0.30706386714273903.
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-04-23 20:59:20,633] Trial 4 finished with value: 0.32616341038400415 and parameters: {'booster': 'gbtree', 'lambda': 9.509821013513949e-08, 'alpha': 0.0059463220665414524, 'max_depth': 7, 'eta': 0.06686859794284719, 'gamma': 0.3836822830508293, 'grow_policy': 'depthwise', 'min_child_weight': 20, 'subsample': 0.14106839073412772, 'colsample_bytree': 0.6043426878377606, 'max_delta_step': 6.8715412069809565}. Best is trial 3 with value: 0.30706386714273903.
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-04-23 21:00:02,515] Trial 5 finished with value: 0.3080739748433196 and parameters: {'booster': 'gbtree', 'lambda': 0.6230518350133054, 'alpha': 2.239015865113238e-08, 'max_depth': 2, 'eta': 0.024058669569455213, 'gamma': 0.001055956506706734, 'grow_policy': 'lossguide', 'min_child_weight': 8, 'subsample': 0.8590626057599248, 'colsample_bytree': 0.521375883176219, 'max_delta_step': 8.079765142549562}. Best is trial 3 with value: 0.30706386714273903.
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-04-23 21:00:13,844] Trial 6 finished with value: 0.3100477051421468 and parameters: {'booster': 'gbtree', 'lambda': 0.00014298415106267986, 'alpha': 0.014759756971811689, 'max_depth': 6, 'eta': 0.08930718269057936, 'gamma': 0.30609786683348433, 'grow_policy': 'depthwise', 'min_child_weight': 5, 'subsample': 0.6460940275626661, 'colsample_bytree': 0.5503656434409774, 'max_delta_step': 1.5233403054322403}. Best is trial 3 with value: 0.30706386714273903.
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-04-23 21:00:43,093] Trial 7 finished with value: 0.31353505792010233 and parameters: {'booster': 'gbtree', 'lambda': 0.5200687843031365, 'alpha': 2.4884298895063708e-08, 'max_depth': 7, 'eta': 0.020624397555110856, 'gamma': 0.06058825712279019, 'grow_policy': 'lossguide', 'min_child_weight': 13, 'subsample': 0.24006297588867803, 'colsample_bytree': 0.8565704254091919, 'max_delta_step': 3.0761626573096423}. Best is trial 3 with value: 0.30706386714273903.
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-04-23 21:01:03,623] Trial 8 finished with value: 0.31217620914704935 and parameters: {'booster': 'gbtree', 'lambda': 1.508569246750751e-06, 'alpha': 1.946367109691848e-08, 'max_depth': 9, 'eta': 0.0934104842761831, 'gamma': 4.245597292862318e-07, 'grow_policy': 'lossguide', 'min_child_weight': 10, 'subsample': 0.8098455906302222, 'colsample_bytree': 0.4463965724970971, 'max_delta_step': 9.410785286479722}. Best is trial 3 with value: 0.30706386714273903.
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-04-23 21:01:49,259] Trial 9 finished with value: 0.3076349555955155 and parameters: {'booster': 'gbtree', 'lambda': 6.533894956812393e-06, 'alpha': 6.576257804078561e-06, 'max_depth': 8, 'eta': 0.011385787449200034, 'gamma': 0.0003488670590700257, 'grow_policy': 'depthwise', 'min_child_weight': 16, 'subsample': 0.5800955274976282, 'colsample_bytree': 0.5510033390650914, 'max_delta_step': 1.482535218983897}. Best is trial 3 with value: 0.30706386714273903.
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [I 2024-04-23 21:04:49,533] Trial 10 finished with value: 0.3139339110895759 and parameters: {'booster': 'gbtree', 'lambda': 0.0036716768061506293, 'alpha': 0.0007697972679558294, 'max_depth': 4, 'eta': 0.011531920845139968, 'gamma': 1.232243415762049e-08, 'grow_policy': 'lossguide', 'min_child_weight': 14, 'subsample': 0.9857232801871406, 'colsample_bytree': 0.034653441399936424, 'max_delta_step': 3.9348859484729553}. Best is trial 3 with value: 0.30706386714273903.

# %%
# After 7.5 hours...
study_xgb = {'booster': 'gbtree',
 'lambda': 9.012384508756378e-07,
 'alpha': 0.7472040331088792,
 'max_depth': 5,
 'eta': 0.01507605562231303,
 'gamma': 1.0214961302342215e-08,
 'grow_policy': 'lossguide',
 'min_child_weight': 5,
 'subsample': 0.9331005225916879,
 'colsample_bytree': 0.25392142363325004,
 'max_delta_step': 5.685109389498008}

# %%
final_params_xgb = dict()
final_params_xgb['clf']=dict(**fixed_params, **study_xgb)

# %% [markdown]
# # Stage 2: Calcule OOF SHAP values

# %%
X_test = test[cat_nom+cat_ord+num_dis+num_con]
X = train[cat_nom+cat_ord+num_dis+num_con]
y = train.y

K=15 # number of bins with Sturge’s rule
SEED=123
kf = StratifiedKFold(n_splits=K, random_state=SEED, shuffle=True)

# %% [markdown]
# ## XGBoost

# %%
pip install shap
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: shap in c:\users\aluno\appdata\roaming\python\python311\site-packages (0.45.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from shap) (1.24.3)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from shap) (1.11.1)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from shap) (1.3.0)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from shap) (2.0.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\programdata\anaconda3\lib\site-packages (from shap) (4.65.0)
# Requirement already satisfied: packaging>20.9 in c:\programdata\anaconda3\lib\site-packages (from shap) (23.1)
# Requirement already satisfied: slicer==0.0.7 in c:\users\aluno\appdata\roaming\python\python311\site-packages (from shap) (0.0.7)
# Requirement already satisfied: numba in c:\programdata\anaconda3\lib\site-packages (from shap) (0.57.1)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from shap) (2.2.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\programdata\anaconda3\lib\site-packages (from numba->shap) (0.40.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)

# %%
shap1_oof = np.zeros((X.shape[0], X.shape[1]))
shap1_test = np.zeros((X_test.shape[0], X_test.shape[1]))
model_shap1_oof = np.zeros(X.shape[0])

for fold, (train_idx, val_idx) in enumerate(kf.split(X=X, y=y)):
    print(f"➜ FOLD :{fold}")
    X_train = X.iloc[train_idx]
    y_train = y.iloc[train_idx]
    X_val = X.iloc[val_idx]
    y_val = y.iloc[val_idx]
    
    start = time.time()
    
    model = XGBClassifier(**final_params_xgb['clf'])
    
    model.fit(X_train, y_train,
              eval_set=[(X_val, y_val)],
              early_stopping_rounds=150,
              verbose=False)
    
    model_shap1_oof[val_idx] += model.predict_proba(X_val)[:,1]
    
    print("Final F1     :", custom_f1(y_val, model_shap1_oof[val_idx]))
    print("Final AUC    :", roc_auc_score(y_val, model_shap1_oof[val_idx]))
    print("Final LogLoss:", log_loss(y_val, model_shap1_oof[val_idx]))

    explainer = shap.TreeExplainer(model)
    
    shap1_oof[val_idx] = explainer.shap_values(X_val)

    shap1_test += explainer.shap_values(X_test) / K

    print(f"elapsed: {time.time()-start:.2f} sec\n")
    
shap1_oof = pd.DataFrame(shap1_oof, columns = [x+"_shap1" for x in X.columns])
shap1_test = pd.DataFrame(shap1_test, columns = [x+"_shap1" for x in X_test.columns])

print("Final F1     :", custom_f1(y, model_shap1_oof))
print("Final AUC    :", roc_auc_score(y, model_shap1_oof))
print("Final LogLoss:", log_loss(y, model_shap1_oof))
# Out:
# ➜ FOLD :0
# C:\Users\aluno\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# Final F1     : 0.6965699208443271
# Final AUC    : 0.899230123180291
# Final LogLoss: 0.2978969732779375
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 27
#      24 print("Final AUC    :", roc_auc_score(y_val, model_shap1_oof[val_idx]))
#      25 print("Final LogLoss:", log_loss(y_val, model_shap1_oof[val_idx]))
# ---> 27 explainer = shap.TreeExplainer(model)
#      29 shap1_oof[val_idx] = explainer.shap_values(X_val)
#      31 shap1_test += explainer.shap_values(X_test) / K
#
# NameError: name 'shap' is not defined
